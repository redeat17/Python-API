# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2e7be3fbf6a6ca5ee22f83c7998246c"

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | imeni poliny osipenko
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | avera
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | cafe
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | do rud
# City not found. Skipping...
# Processing Record 20 of Set 1 | potosi
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | kurilsk
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | bandarbeyla
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | valky
# Processing Record 30 of Set 1 | gizo
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | yumen
# Processing Record 37 of Set 1 | bandar-e lengeh
# Processing Record 38 of Set 1 | batemans bay
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | opuwo
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | necochea
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | pathein
# Processing Record 49 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 1 | kununurra
# Processing Record 0 of Set 2 | mount gambier
# Processing Record 1 of Set 2 | revda
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | kiunga
# Processing Record 5 of Set 2 | teguise
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | marsh harbour
# Processing Record 8 of Set 2 | saint-augustin
# Processing Record 9 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 2 | ndola
# Processing Record 11 of Set 2 | candolim
# Processing Record 12 of Set 2 | oga
# Processing Record 13 of Set 2 | black river
# Processing Record 14 of Set 2 | ereymentau
# Processing Record 15 of Set 2 | stillwater
# Processing Record 16 of Set 2 | beruwala
# Processing Record 17 of Set 2 | comodoro rivadavia
# Processing Record 18 of Set 2 | diffa
# Processing Record 19 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | eyl
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | amahai
# Processing Record 24 of Set 2 | wuwei
# Processing Record 25 of Set 2 | okato
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | chimbote
# Processing Record 30 of Set 2 | argelia
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | naryan-mar
# Processing Record 33 of Set 2 | alberton
# Processing Record 34 of Set 2 | ballina
# Processing Record 35 of Set 2 | olafsvik
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | erenhot
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | egvekinot
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | warah
# Processing Record 42 of Set 2 | amapa
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | dicabisagan
# Processing Record 45 of Set 2 | alamosa
# Processing Record 46 of Set 2 | senmonorom
# City not found. Skipping...
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | cap malheureux
# Processing Record 49 of Set 2 | kautokeino
# Processing Record 0 of Set 3 | stromness
# Processing Record 1 of Set 3 | kaka
# Processing Record 2 of Set 3 | belaya gora
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | komarichi
# Processing Record 6 of Set 3 | tabuk
# Processing Record 7 of Set 3 | vila franca do campo
# Processing Record 8 of Set 3 | upernavik
# Processing Record 9 of Set 3 | lamu
# Processing Record 10 of Set 3 | lagos
# Processing Record 11 of Set 3 | fairbanks
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | ipixuna
# Processing Record 14 of Set 3 | pacific grove
# Processing Record 15 of Set 3 | otofuke
# Processing Record 16 of Set 3 | sorong
# Processing Record 17 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | laguna
# Processing Record 24 of Set 3 | nizwa
# Processing Record 25 of Set 3 | puerto escondido
# Processing Record 26 of Set 3 | zhigansk
# Processing Record 27 of Set 3 | lata
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | the pas
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | maceio
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | waddan
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | sao filipe
# Processing Record 39 of Set 3 | colorado springs
# Processing Record 40 of Set 3 | ornskoldsvik
# Processing Record 41 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 3 | aswan
# Processing Record 43 of Set 3 | xuddur
# Processing Record 44 of Set 3 | auki
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | tayu
# Processing Record 47 of Set 3 | terryville
# Processing Record 48 of Set 3 | tambacounda
# Processing Record 49 of Set 3 | harper
# Processing Record 0 of Set 4 | temple
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | mozarlandia
# Processing Record 3 of Set 4 | shibarghan
# City not found. Skipping...
# Processing Record 4 of Set 4 | finnsnes
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | sangar
# Processing Record 8 of Set 4 | dikson
# Processing Record 9 of Set 4 | point fortin
# Processing Record 10 of Set 4 | novovasylivka
# Processing Record 11 of Set 4 | basco
# Processing Record 12 of Set 4 | pasighat
# Processing Record 13 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 4 | paamiut
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | farah
# Processing Record 18 of Set 4 | srednekolymsk
# Processing Record 19 of Set 4 | hilo
# Processing Record 20 of Set 4 | marzuq
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | hirara
# Processing Record 23 of Set 4 | ulaanbaatar
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | kavaratti
# Processing Record 26 of Set 4 | macherla
# Processing Record 27 of Set 4 | luena
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | ranot
# Processing Record 30 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 4 | narsaq
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | mildura
# Processing Record 34 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 4 | tilichiki
# Processing Record 36 of Set 4 | ust-tsilma
# Processing Record 37 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 4 | vila
# Processing Record 39 of Set 4 | meulaboh
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | lander
# Processing Record 43 of Set 4 | husavik
# Processing Record 44 of Set 4 | poum
# Processing Record 45 of Set 4 | kamyshevatskaya
# Processing Record 46 of Set 4 | smithers
# Processing Record 47 of Set 4 | tevaitoa
# Processing Record 48 of Set 4 | biskamzha
# Processing Record 49 of Set 4 | inuvik
# Processing Record 0 of Set 5 | tiznit
# Processing Record 1 of Set 5 | linhares
# Processing Record 2 of Set 5 | nouadhibou
# Processing Record 3 of Set 5 | pangnirtung
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | benemerito de las americas
# Processing Record 6 of Set 5 | trinidad
# Processing Record 7 of Set 5 | liverpool
# Processing Record 8 of Set 5 | puerto boyaca
# Processing Record 9 of Set 5 | koundara
# Processing Record 10 of Set 5 | vestmannaeyjar
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | maba
# Processing Record 13 of Set 5 | miranda
# Processing Record 14 of Set 5 | ho
# City not found. Skipping...
# Processing Record 15 of Set 5 | tilsonburg
# City not found. Skipping...
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | chaohu
# Processing Record 18 of Set 5 | osmena
# Processing Record 19 of Set 5 | fort nelson
# Processing Record 20 of Set 5 | burica
# City not found. Skipping...
# Processing Record 21 of Set 5 | kitimat
# Processing Record 22 of Set 5 | souillac
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | parichha
# Processing Record 25 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 5 | zavallya
# Processing Record 27 of Set 5 | eureka
# Processing Record 28 of Set 5 | goderich
# Processing Record 29 of Set 5 | antalaha
# Processing Record 30 of Set 5 | henties bay
# Processing Record 31 of Set 5 | mabaruma
# Processing Record 32 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 5 | sola
# Processing Record 34 of Set 5 | santa rosalia
# Processing Record 35 of Set 5 | manokwari
# Processing Record 36 of Set 5 | huarmey
# Processing Record 37 of Set 5 | tasiilaq
# Processing Record 38 of Set 5 | bhainsa
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | fukue
# Processing Record 41 of Set 5 | kapoeta
# Processing Record 42 of Set 5 | port hardy
# Processing Record 43 of Set 5 | cadereyta
# Processing Record 44 of Set 5 | kaeo
# Processing Record 45 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 5 | qaanaaq
# Processing Record 47 of Set 5 | bosaso
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | torbay
# Processing Record 0 of Set 6 | rundu
# Processing Record 1 of Set 6 | padang
# Processing Record 2 of Set 6 | ponta pora
# Processing Record 3 of Set 6 | norman wells
# Processing Record 4 of Set 6 | baraboo
# Processing Record 5 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 6 | kunya
# Processing Record 7 of Set 6 | gornyy
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | rapid valley
# Processing Record 10 of Set 6 | sinnamary
# Processing Record 11 of Set 6 | kungurtug
# Processing Record 12 of Set 6 | salinopolis
# Processing Record 13 of Set 6 | sao jose dos pinhais
# Processing Record 14 of Set 6 | inverell
# Processing Record 15 of Set 6 | sundumbili
# Processing Record 16 of Set 6 | pljevlja
# Processing Record 17 of Set 6 | oum hadjer
# Processing Record 18 of Set 6 | dasoguz
# Processing Record 19 of Set 6 | talnakh
# Processing Record 20 of Set 6 | sonqor
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | crestview
# Processing Record 23 of Set 6 | tarakan
# Processing Record 24 of Set 6 | sitka
# Processing Record 25 of Set 6 | arraial do cabo
# Processing Record 26 of Set 6 | morant bay
# Processing Record 27 of Set 6 | martapura
# Processing Record 28 of Set 6 | tres arroyos
# Processing Record 29 of Set 6 | roma
# Processing Record 30 of Set 6 | walvis bay
# Processing Record 31 of Set 6 | manicore
# Processing Record 32 of Set 6 | bonthe
# Processing Record 33 of Set 6 | alyangula
# Processing Record 34 of Set 6 | abu dhabi
# Processing Record 35 of Set 6 | sotnikovo
# Processing Record 36 of Set 6 | tecoanapa
# Processing Record 37 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 38 of Set 6 | bundaberg
# Processing Record 39 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | manjacaze
# Processing Record 43 of Set 6 | broken hill
# Processing Record 44 of Set 6 | prince george
# Processing Record 45 of Set 6 | roseto degli abruzzi
# Processing Record 46 of Set 6 | toora-khem
# Processing Record 47 of Set 6 | quatre cocos
# Processing Record 48 of Set 6 | haines junction
# Processing Record 49 of Set 6 | voyinka
# Processing Record 0 of Set 7 | kattivakkam
# Processing Record 1 of Set 7 | port-gentil
# Processing Record 2 of Set 7 | northam
# Processing Record 3 of Set 7 | okhotsk
# Processing Record 4 of Set 7 | pasni
# Processing Record 5 of Set 7 | byron bay
# Processing Record 6 of Set 7 | mbala
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | keighley
# Processing Record 9 of Set 7 | camacha
# Processing Record 10 of Set 7 | yantarnyy
# Processing Record 11 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 7 | cravo norte
# Processing Record 13 of Set 7 | la libertad
# Processing Record 14 of Set 7 | quelimane
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | ca mau
# Processing Record 17 of Set 7 | moerai
# Processing Record 18 of Set 7 | cilegon
# Processing Record 19 of Set 7 | artyom
# Processing Record 20 of Set 7 | ratnagiri
# Processing Record 21 of Set 7 | grindavik
# Processing Record 22 of Set 7 | sri aman
# Processing Record 23 of Set 7 | verkhoyansk
# Processing Record 24 of Set 7 | filadelfia
# Processing Record 25 of Set 7 | vernon
# Processing Record 26 of Set 7 | malanje
# Processing Record 27 of Set 7 | san cristobal
# Processing Record 28 of Set 7 | najran
# Processing Record 29 of Set 7 | thap than
# Processing Record 30 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | rockhampton
# Processing Record 33 of Set 7 | wanaka
# Processing Record 34 of Set 7 | kastamonu
# Processing Record 35 of Set 7 | orlik
# Processing Record 36 of Set 7 | trelew
# Processing Record 37 of Set 7 | sena madureira
# Processing Record 38 of Set 7 | saint-philippe
# Processing Record 39 of Set 7 | plaiesii-de-jos
# City not found. Skipping...
# Processing Record 40 of Set 7 | katherine
# Processing Record 41 of Set 7 | christchurch
# Processing Record 42 of Set 7 | vanavara
# Processing Record 43 of Set 7 | date
# Processing Record 44 of Set 7 | karratha
# Processing Record 45 of Set 7 | ravar
# Processing Record 46 of Set 7 | longyearbyen
# Processing Record 47 of Set 7 | iwaki
# Processing Record 48 of Set 7 | leningradskiy
# Processing Record 49 of Set 7 | gorodishche
# Processing Record 0 of Set 8 | cangzhou
# Processing Record 1 of Set 8 | buenos aires
# Processing Record 2 of Set 8 | severo-kurilsk
# Processing Record 3 of Set 8 | sakiai
# Processing Record 4 of Set 8 | saint-pierre
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | bandundu
# Processing Record 7 of Set 8 | cabra
# Processing Record 8 of Set 8 | nuuk
# Processing Record 9 of Set 8 | port lincoln
# Processing Record 10 of Set 8 | yenagoa
# Processing Record 11 of Set 8 | la grande
# Processing Record 12 of Set 8 | sabang
# Processing Record 13 of Set 8 | noyabrsk
# Processing Record 14 of Set 8 | porto belo
# Processing Record 15 of Set 8 | bulolo
# Processing Record 16 of Set 8 | corinto
# Processing Record 17 of Set 8 | isabela
# Processing Record 18 of Set 8 | saint anthony
# Processing Record 19 of Set 8 | prince rupert
# Processing Record 20 of Set 8 | yar-sale
# Processing Record 21 of Set 8 | bageshwar
# Processing Record 22 of Set 8 | naze
# Processing Record 23 of Set 8 | lindi
# Processing Record 24 of Set 8 | poco verde
# Processing Record 25 of Set 8 | ossora
# Processing Record 26 of Set 8 | santa maria
# Processing Record 27 of Set 8 | lorengau
# Processing Record 28 of Set 8 | beira
# Processing Record 29 of Set 8 | tezu
# Processing Record 30 of Set 8 | marawi
# Processing Record 31 of Set 8 | namatanai
# Processing Record 32 of Set 8 | sungaipenuh
# Processing Record 33 of Set 8 | telimele
# Processing Record 34 of Set 8 | troitsko-pechorsk
# Processing Record 35 of Set 8 | shimanovsk
# Processing Record 36 of Set 8 | port hedland
# Processing Record 37 of Set 8 | kamenka
# Processing Record 38 of Set 8 | puerto gaitan
# Processing Record 39 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 8 | uglovskoye
# Processing Record 41 of Set 8 | ayagoz
# Processing Record 42 of Set 8 | terenos
# Processing Record 43 of Set 8 | kraslava
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | sungairaya
# Processing Record 46 of Set 8 | le port
# Processing Record 47 of Set 8 | muravlenko
# Processing Record 48 of Set 8 | kurkino
# Processing Record 49 of Set 8 | along
# Processing Record 0 of Set 9 | taywarah
# Processing Record 1 of Set 9 | caborca
# Processing Record 2 of Set 9 | ayr
# Processing Record 3 of Set 9 | hamilton
# Processing Record 4 of Set 9 | shimoda
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | awbari
# Processing Record 7 of Set 9 | honiara
# Processing Record 8 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 9 of Set 9 | horsham
# Processing Record 10 of Set 9 | bentiu
# Processing Record 11 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 9 | qorveh
# Processing Record 13 of Set 9 | aksarka
# Processing Record 14 of Set 9 | gawler
# Processing Record 15 of Set 9 | hofn
# Processing Record 16 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 17 of Set 9 | tessalit
# Processing Record 18 of Set 9 | nome
# Processing Record 19 of Set 9 | saint-joseph
# Processing Record 20 of Set 9 | arman
# Processing Record 21 of Set 9 | luderitz
# Processing Record 22 of Set 9 | luganville
# Processing Record 23 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 24 of Set 9 | kudahuvadhoo
# Processing Record 25 of Set 9 | santa rita do sapucai
# Processing Record 26 of Set 9 | port augusta
# Processing Record 27 of Set 9 | irituia
# Processing Record 28 of Set 9 | rocha
# Processing Record 29 of Set 9 | nisia floresta
# Processing Record 30 of Set 9 | excelsior springs
# Processing Record 31 of Set 9 | parrita
# Processing Record 32 of Set 9 | caloundra
# Processing Record 33 of Set 9 | lieksa
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 36 of Set 9 | hammerfest
# Processing Record 37 of Set 9 | eunice
# Processing Record 38 of Set 9 | narasannapeta
# Processing Record 39 of Set 9 | beloha
# Processing Record 40 of Set 9 | orillia
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | flinders
# Processing Record 43 of Set 9 | tocopilla
# Processing Record 44 of Set 9 | zaria
# Processing Record 45 of Set 9 | uruguaiana
# Processing Record 46 of Set 9 | te anau
# Processing Record 47 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 9 | kahului
# Processing Record 49 of Set 9 | praia da vitoria
# Processing Record 0 of Set 10 | kloulklubed
# Processing Record 1 of Set 10 | kawalu
# Processing Record 2 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 10 | constitucion
# Processing Record 4 of Set 10 | cairns
# Processing Record 5 of Set 10 | ixtapa
# Processing Record 6 of Set 10 | vera cruz
# Processing Record 7 of Set 10 | somerset
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | kavieng
# Processing Record 10 of Set 10 | katangli
# Processing Record 11 of Set 10 | letlhakane
# Processing Record 12 of Set 10 | hanzhong
# Processing Record 13 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 10 | esna
# Processing Record 15 of Set 10 | picton
# Processing Record 16 of Set 10 | aykhal
# Processing Record 17 of Set 10 | beneditinos
# Processing Record 18 of Set 10 | zyryanka
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | kismayo
# Processing Record 22 of Set 10 | koslan
# Processing Record 23 of Set 10 | soderhamn
# Processing Record 24 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 10 | banda aceh
# Processing Record 26 of Set 10 | balestrand
# Processing Record 27 of Set 10 | shingu
# Processing Record 28 of Set 10 | tautira
# Processing Record 29 of Set 10 | kovur
# Processing Record 30 of Set 10 | vostok
# Processing Record 31 of Set 10 | chulym
# Processing Record 32 of Set 10 | azrow
# City not found. Skipping...
# Processing Record 33 of Set 10 | nizhniy kuranakh
# Processing Record 34 of Set 10 | aden
# Processing Record 35 of Set 10 | falam
# Processing Record 36 of Set 10 | salalah
# Processing Record 37 of Set 10 | huayapam
# City not found. Skipping...
# Processing Record 38 of Set 10 | gabu
# Processing Record 39 of Set 10 | baykit
# Processing Record 40 of Set 10 | pontes e lacerda
# Processing Record 41 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 42 of Set 10 | aleksandriya
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | ngunguru
# Processing Record 45 of Set 10 | ribas do rio pardo
# Processing Record 46 of Set 10 | lerwick
# Processing Record 47 of Set 10 | hanting
# Processing Record 48 of Set 10 | pombia
# Processing Record 49 of Set 10 | ust-karsk
# Processing Record 0 of Set 11 | burleson
# Processing Record 1 of Set 11 | jelgava
# Processing Record 2 of Set 11 | tahta
# Processing Record 3 of Set 11 | teahupoo
# Processing Record 4 of Set 11 | talaja
# Processing Record 5 of Set 11 | cayenne
# Processing Record 6 of Set 11 | san blas
# Processing Record 7 of Set 11 | vao
# Processing Record 8 of Set 11 | solnechnyy
# Processing Record 9 of Set 11 | altay
# Processing Record 10 of Set 11 | seminole
# Processing Record 11 of Set 11 | broome
# Processing Record 12 of Set 11 | shelbyville
# Processing Record 13 of Set 11 | labuhan
# Processing Record 14 of Set 11 | shumskiy
# Processing Record 15 of Set 11 | cockburn town
# Processing Record 16 of Set 11 | lichinga
# Processing Record 17 of Set 11 | les cayes
# Processing Record 18 of Set 11 | pokhara
# Processing Record 19 of Set 11 | tabas
# Processing Record 20 of Set 11 | taoudenni
# Processing Record 21 of Set 11 | djambala
# Processing Record 22 of Set 11 | hay river
# Processing Record 23 of Set 11 | bathsheba
# Processing Record 24 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 11 | zhanakorgan
# Processing Record 27 of Set 11 | san quintin
# Processing Record 28 of Set 11 | beaumont
# Processing Record 29 of Set 11 | severnyy
# Processing Record 30 of Set 11 | riobamba
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | osoyoos
# Processing Record 33 of Set 11 | itarema
# Processing Record 34 of Set 11 | san ramon
# Processing Record 35 of Set 11 | ndioum
# Processing Record 36 of Set 11 | marfino
# Processing Record 37 of Set 11 | tiarei
# Processing Record 38 of Set 11 | aasiaat
# Processing Record 39 of Set 11 | forres
# Processing Record 40 of Set 11 | tailai
# Processing Record 41 of Set 11 | hudiksvall
# Processing Record 42 of Set 11 | komsomolskiy
# Processing Record 43 of Set 11 | umm lajj
# Processing Record 44 of Set 11 | campbellton
# Processing Record 45 of Set 11 | qaqortoq
# Processing Record 46 of Set 11 | san joaquin
# Processing Record 47 of Set 11 | pitea
# Processing Record 48 of Set 11 | beisfjord
# Processing Record 49 of Set 11 | abha
# Processing Record 0 of Set 12 | wangaratta
# Processing Record 1 of Set 12 | parana
# Processing Record 2 of Set 12 | los llanos de aridane
# Processing Record 3 of Set 12 | doha
# Processing Record 4 of Set 12 | urbana
# Processing Record 5 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 6 of Set 12 | cartagena
# Processing Record 7 of Set 12 | samarai
# Processing Record 8 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 9 of Set 12 | altona
# Processing Record 10 of Set 12 | saint-francois
# Processing Record 11 of Set 12 | zykovo
# Processing Record 12 of Set 12 | ketchikan
# Processing Record 13 of Set 12 | mae sot
# Processing Record 14 of Set 12 | letlhakeng
# Processing Record 15 of Set 12 | luba
# Processing Record 16 of Set 12 | lampang
# Processing Record 17 of Set 12 | jiwani
# Processing Record 18 of Set 12 | mao
# Processing Record 19 of Set 12 | lavrentiya
# Processing Record 20 of Set 12 | nishihara
# Processing Record 21 of Set 12 | fairfield
# Processing Record 22 of Set 12 | redcar
# Processing Record 23 of Set 12 | mehamn
# Processing Record 24 of Set 12 | guangyuan
# Processing Record 25 of Set 12 | ligayan
# Processing Record 26 of Set 12 | bahia honda
# Processing Record 27 of Set 12 | jimeta
# Processing Record 28 of Set 12 | moratuwa
# Processing Record 29 of Set 12 | thanh hoa
# Processing Record 30 of Set 12 | joinville
# Processing Record 31 of Set 12 | chicama
# Processing Record 32 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 12 | mayachnyy
# Processing Record 34 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 12 | aljezur
# Processing Record 36 of Set 12 | manta
# Processing Record 37 of Set 12 | formosa do rio preto
# Processing Record 38 of Set 12 | tungor
# Processing Record 39 of Set 12 | kaitangata
# Processing Record 40 of Set 12 | rio gallegos
# Processing Record 41 of Set 12 | mitsamiouli
# Processing Record 42 of Set 12 | bolgar
# Processing Record 43 of Set 12 | margate
# Processing Record 44 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set 12 | eastbourne
# Processing Record 46 of Set 12 | roseburg
# Processing Record 47 of Set 12 | norden
# Processing Record 48 of Set 12 | caravelas
# Processing Record 49 of Set 12 | beringovskiy
# Processing Record 0 of Set 13 | sibolga
# Processing Record 1 of Set 13 | saint george
# Processing Record 2 of Set 13 | sahuaripa
# Processing Record 3 of Set 13 | balykshi
# Processing Record 4 of Set 13 | tombouctou
# Processing Record 5 of Set 13 | iqaluit
# Processing Record 6 of Set 13 | dayong
# Processing Record 7 of Set 13 | biloela
# Processing Record 8 of Set 13 | la union
# Processing Record 9 of Set 13 | daltenganj
# Processing Record 10 of Set 13 | anadyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)
city_data_pd
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      new norfolk -42.78  147.06     66.99        59          46        7.00
# 1      provideniya  64.38 -173.30     35.60        93          90       15.66
# 2            vaini -21.20 -175.20     78.80        88          75        5.82
# 3      yellowknife  62.46 -114.35      3.20        91          90        8.05
# 4    mar del plata -38.00  -57.56     55.00        87          20        3.36
# ..             ...    ...     ...       ...       ...         ...         ...
# 551         dayong  25.02  118.29     77.00        61          40        4.47
# 552        biloela -24.42  150.50     95.94        25           0        8.34
# 553       la union  -5.40  -80.75     65.89        75         100       10.00
# 554     daltenganj  24.03   84.07     75.11        57           0        4.07
# 555         anadyr  64.75  177.48     33.80        86           0       29.08
#
#     Country        Date
# 0        AU  1605495131
# 1        RU  1605495131
# 2        TO  1605495131
# 3        CA  1605495131
# 4        AR  1605495047
# ..      ...         ...
# 551      CN  1605495190
# 552      AU  1605495190
# 553      PE  1605495190
# 554      IN  1605495190
# 555      RU  1605495191
#
# [556 rows x 9 columns]

# %%
# Show Record Count
city_data_pd.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  556.000000  556.000000  556.000000  556.000000  556.000000  556.000000
# mean    19.745054   19.236637   56.816205   72.951439   51.535971    8.465827
# std     33.385012   92.258386   24.834639   19.473784   40.573996    5.900185
# min    -54.800000 -179.170000  -22.250000   16.000000    0.000000    0.290000
# 25%     -8.787500  -60.340000   40.042500   62.000000    3.750000    3.650000
# 50%     22.910000   23.695000   64.400000   78.000000   53.000000    7.485000
# 75%     48.060000   99.997500   75.707500   88.000000   94.000000   11.410000
# max     78.220000  179.320000  102.990000  100.000000  100.000000   40.260000
#
#                Date
# count  5.560000e+02
# mean   1.605495e+09
# std    5.980224e+01
# min    1.605495e+09
# 25%    1.605495e+09
# 50%    1.605495e+09
# 75%    1.605495e+09
# max    1.605495e+09

# %%
city_data_pd.to_csv("City_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index                                 
dirty_city_data
#city_data_pd.describe()
# Out:
# Int64Index([], dtype='int64')

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    new norfolk -42.78  147.06     66.99        59          46        7.00
# 1    provideniya  64.38 -173.30     35.60        93          90       15.66
# 2          vaini -21.20 -175.20     78.80        88          75        5.82
# 3    yellowknife  62.46 -114.35      3.20        91          90        8.05
# 4  mar del plata -38.00  -57.56     55.00        87          20        3.36
#
#   Country        Date
# 0      AU  1605495131
# 1      RU  1605495131
# 2      TO  1605495131
# 3      CA  1605495131
# 4      AR  1605495047

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv("../output_data/cities.csv", index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig2.png")
# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build scatter plot for latitude vs. cloudiness 
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig3.png")
# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind_speed 
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("wind_speed")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig4.png")
# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
plt.savefig("../output_data/Fig5.png")
# Out:
# The r-value is: 0.7538300603028734

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(-50, 20))
plt.savefig("../output_data/Fig6.png")
# Out:
# The r-value is: 0.2141610093734674

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(6,30))
plt.savefig("../output_data/Fig7.png")
# Out:
# The r-value is: 0.11194225566347579

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(-50, 20))
plt.savefig("../output_data/Fig8.png")
# Out:
# The r-value is: 0.07402732442083877

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(6, 30))
plt.savefig("../output_data/Fig9.png")
# Out:
# The r-value is: 0.11521492559099987

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(-50, 20))
plt.savefig("../output_data/Fig10.png")
# Out:
# The r-value is: 0.16422032504583792

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(6,30))
plt.savefig("../output_data/Fig11.png")
# Out:
# The r-value is: 0.06551790337512013

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(-50, 20))
plt.savefig("../output_data/Fig12.png")
# Out:
# The r-value is: 0.09864316364381355

# %%
# Out:
# The r-value is: 0.017128274759839232
