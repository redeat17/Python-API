# %%
# Dependencies
import requests
from config import api_key
import time

# Store a search term
query = "election"

# Search for articles published between a begin and end date
begin_date = "20201103"
end_date = "20201103"

query_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}&api-key={api_key}&begin_date={begin_date}&end_date={end_date}'
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=8GDHAfyIhsG4sTWjQDgrBiBBKfTp50Gg&begin_date=20201103&end_date=20201103'

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Modeling key battleground states.',
#     'web_url': 'https://www.nytimes.com/interactive/2020/11/03/us/elections/forecast-president.html',
#     'snippet': 'Modeling key battleground states.',
#     'lead_paragraph': 'Modeling key battleground states.',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Election Needles: President',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'internal-election-open',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'glocations', 'value': 'United States', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Elections', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
# ...

# %%
articles_list = articles["response"]["docs"]

for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]} \n Learn more at: {article["web_url"]}')
    print('---------------------------')
# Out:
# A snippet from the article: Modeling key battleground states.
#  Learn more at: https://www.nytimes.com/interactive/2020/11/03/us/elections/forecast-president.html
# ---------------------------
# A snippet from the article: See full results and maps from the Nevada elections.
#  Learn more at: https://www.nytimes.com/interactive/2020/11/03/us/elections/results-nevada.html
# ---------------------------
# A snippet from the article: See full results and maps from the Vermont elections.
#  Learn more at: https://www.nytimes.com/interactive/2020/11/03/us/elections/results-vermont.html
# ---------------------------
# A snippet from the article: See full results and maps from the Alaska elections.
#  Learn more at: https://www.nytimes.com/interactive/2020/11/03/us/elections/results-alaska.html
# ---------------------------
# A snippet from the article: See full results and maps from the Iowa elections.
# ...

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Empty list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    # create query with page number
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}&page={page}"
        
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
for article in articles_list:
    print(article['snippet'])
    print('---------------------------')
# Out:
# Tuesday: Today’s the day. Here’s everything you need to catch up.
# ---------------------------
# See full results and maps from the Alabama elections.
# ---------------------------
# See full results and maps from the Maryland elections.
# ---------------------------
# See full results and maps from the Mississippi elections.
# ---------------------------
# See full results and maps from the 2020 governor elections.
# ---------------------------
# See full results and maps from the Alaska election.
# ---------------------------
# See full results and maps from the Florida elections.
# ---------------------------
# See full results and maps from the 2020 presidential election.
# ---------------------------
# See full results and maps from the Arizona elections.
# ---------------------------
# See full results and maps from the Hawaii elections.
# ---------------------------
# See full results and maps from the Utah elections.
# ---------------------------
# ...
